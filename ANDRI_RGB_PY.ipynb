# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

img_path = "Andri.jpg"
img = cv2.imread(img_path)
print(img.shape)

fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)

R, G, B = fix_img[:,:,0], fix_img[:,:,1], fix_img[:,:,2]
print(np.array(fix_img))
# Out:
# (1600, 900, 3)
# [[[230 234 237]
#   [229 233 236]
#   [229 233 236]
#   ...
#   [179 171 158]
#   [180 172 159]
#   [180 172 159]]
#
#  [[230 234 237]
#   [229 233 236]
#   [229 233 236]
#   ...
#   [179 171 158]
#   [180 172 159]
#   [181 173 160]]
#
#  [[230 234 237]
#   [229 233 236]
#   [229 233 236]
#   ...
#   [179 171 158]
#   [180 172 159]
#   [181 173 160]]
#
#  ...
#
#  [[191 183 172]
#   [190 182 171]
#   [189 181 170]
#   ...
#   [ 72  73  75]
#   [ 71  72  74]
#   [ 70  71  73]]
#
#  [[190 182 171]
#   [190 182 171]
#   [190 182 171]
#   ...
#   [ 70  71  73]
#   [ 70  71  73]
#   [ 70  71  73]]
#
#  [[189 181 170]
#   [190 182 171]
#   [191 183 172]
#   ...
#   [ 68  69  71]
#   [ 69  70  72]
#   [ 70  71  73]]]

# %%
fix_img[:] = np.max(fix_img, axis=-1, keepdims=1)/2 + np.min(fix_img, axis=-1, keepdims=1)/2
print(np.array(fix_img[:]))


plt.axis('off')
plt.imshow(fix_img[:])
plt.savefig('Lightness', bbox_inches= 'tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7df14ccd3fbd> in <cell line: 1>()
# ----> 1 fix_img[:] = np.max(fix_img, axis=-1, keepdims=1)/2 + np.min(fix_img, axis=-1, keepdims=1)/2
#       2 print(np.array(fix_img[:]))
#       3
#       4
#       5 plt.axis('off')
#
# NameError: name 'np' is not defined

# %%
gray_img = np.mean(fix_img, axis=-1)
print(np.array(gray_img))

plt.axis('off')
plt.imshow(gray_img)
plt.savefig('Average', bbox_inches= 'tight')
# Out:
# [[233. 232. 232. ... 168. 169. 169.]
#  [233. 232. 232. ... 168. 169. 170.]
#  [233. 232. 232. ... 168. 169. 170.]
#  ...
#  [181. 180. 179. ...  73.  72.  71.]
#  [180. 180. 180. ...  71.  71.  71.]
#  [179. 180. 181. ...  69.  70.  71.]]

# %%
lumi_img = (0.2126*R) + (0.7152*G) + (0.0722*B)
print(np.array(lumi_img))

plt.axis('off')
plt.imshow(lumi_img, cmap='gray')
plt.savefig('Luminosity', bbox_inches= 'tight')
# Out:
# [[233. 232. 232. ... 168. 169. 169.]
#  [233. 232. 232. ... 168. 169. 170.]
#  [233. 232. 232. ... 168. 169. 170.]
#  ...
#  [181. 180. 179. ...  73.  72.  71.]
#  [180. 180. 180. ...  71.  71.  71.]
#  [179. 180. 181. ...  69.  70.  71.]]

# %%
wav_img = (0.299*R) + (0.587*G) + (0.114*B)
print(np.array(wav_img))

plt.axis('off')
plt.imshow(wav_img, cmap='gray')
plt.savefig('Weighted Average', bbox_inches= 'tight')
# Out:
# [[233. 232. 232. ... 168. 169. 169.]
#  [233. 232. 232. ... 168. 169. 170.]
#  [233. 232. 232. ... 168. 169. 170.]
#  ...
#  [181. 180. 179. ...  73.  72.  71.]
#  [180. 180. 180. ...  71.  71.  71.]
#  [179. 180. 181. ...  69.  70.  71.]]
